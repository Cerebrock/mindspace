# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from time import sleep
import numpy as np
# %matplotlib inline

# %%
#rgb
cmap = cm.get_cmap('viridis')

# %%
j = 1
for i in np.logspace(0.55,0.7,10)/10:
    rgba = cmap(i)
    c = rgba[:-1]
    h,w = 50, 50
    img = np.tile(c, (h,w,1))
    plt.imshow(img)
    plt.imsave(fr'C:\Users\mgrinberg\Desktop\disc c\Investigación\Neurocomp\static\media\colores/{j}.png', img)
    plt.axis('off')
    plt.show()
    j += 1
